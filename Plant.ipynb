# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications import (
    MobileNetV2,
    ResNet50,
    EfficientNetB0
)

import os

# ================= PARAMETERS =================
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 15
NUM_CLASSES = 3

TRAIN_DIR = "dataset/train/train"
VAL_DIR = "dataset/validation/validation"
TEST_DIR = "dataset/test/test"

# ================= DATA GENERATORS =================
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    zoom_range=0.2,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

val_data = val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

test_data = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

# ================= MODELS TO TEST =================
models_to_try = {
    "MobileNetV2": MobileNetV2,
    "EfficientNetB4": EfficientNetB4,
    "DenseNet121": DenseNet121,
    "ResNet50": ResNet50
}

best_accuracy = 0
best_model_name = ""
best_model = None

# ================= TRAINING LOOP =================
for model_name, model_class in models_to_try.items():
    print(f"\n🚀 Training {model_name}...\n")

    base_model = model_class(
        weights="imagenet",
        include_top=False,
        input_shape=(224, 224, 3)
    )
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation="relu")(x)
    x = Dropout(0.5)(x)
    output = Dense(NUM_CLASSES, activation="softmax")(x)

    model = Model(inputs=base_model.input, outputs=output)

    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    model.fit(
        train_data,
        epochs=EPOCHS,
        validation_data=val_data,
        verbose=1
    )

    loss, accuracy = model.evaluate(test_data, verbose=0)
    print(f"✅ {model_name} Test Accuracy: {accuracy * 100:.2f}%")

    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_model_name = model_name
        best_model = model

# ================= SAVE BEST MODEL =================
best_model.save("best_plant_disease_model.h5")

print("\n================ FINAL RESULT ================")
print(f"🏆 Best Model      : {best_model_name}")
print(f"🎯 Best Accuracy   : {best_accuracy * 100:.2f}%")
print("💾 Model Saved As  : best_plant_disease_model.h5")
print("=============================================")
# Out:
# Found 1322 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.
# Found 151 images belonging to 3 classes.
#
# 🚀 Training MobileNetV2...
#
# Epoch 1/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 137s 3s/step - accuracy: 0.5303 - loss: 1.0496 - val_accuracy: 0.8833 - val_loss: 0.4961
# Epoch 2/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.7648 - loss: 0.5831 - val_accuracy: 0.9167 - val_loss: 0.3216
# Epoch 3/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 74s 2s/step - accuracy: 0.8480 - loss: 0.3939 - val_accuracy: 0.9333 - val_loss: 0.2499
# Epoch 4/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 74s 2s/step - accuracy: 0.8903 - loss: 0.3234 - val_accuracy: 0.9333 - val_loss: 0.2200
# Epoch 5/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 116s 3s/step - accuracy: 0.9085 - loss: 0.2708 - val_accuracy: 0.9333 - val_loss: 0.1964
# Epoch 6/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9221 - loss: 0.2324 - val_accuracy: 0.9333 - val_loss: 0.1848
# Epoch 7/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9289 - loss: 0.2143 - val_accuracy: 0.9500 - val_loss: 0.1725
# Epoch 8/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 135s 3s/step - accuracy: 0.9410 - loss: 0.1910 - val_accuracy: 0.9500 - val_loss: 0.1604
# Epoch 9/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 127s 3s/step - accuracy: 0.9493 - loss: 0.1637 - val_accuracy: 0.9500 - val_loss: 0.1610
# Epoch 10/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 131s 3s/step - accuracy: 0.9531 - loss: 0.1572 - val_accuracy: 0.9500 - val_loss: 0.1546
# Epoch 11/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9508 - loss: 0.1482 - val_accuracy: 0.9500 - val_loss: 0.1496
# Epoch 12/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 113s 3s/step - accuracy: 0.9561 - loss: 0.1471 - val_accuracy: 0.9500 - val_loss: 0.1410
# Epoch 13/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.9622 - loss: 0.1321 - val_accuracy: 0.9500 - val_loss: 0.1323
# Epoch 14/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9561 - loss: 0.1330 - val_accuracy: 0.9500 - val_loss: 0.1347
# Epoch 15/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.9637 - loss: 0.1143 - val_accuracy: 0.9500 - val_loss: 0.1364
# ✅ MobileNetV2 Test Accuracy: 97.35%
#
# 🚀 Training ResNet50...
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# Epoch 1/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 112s 3s/step - accuracy: 0.3366 - loss: 1.2720 - val_accuracy: 0.4667 - val_loss: 1.0791
# Epoch 2/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.3192 - loss: 1.2249 - val_accuracy: 0.4167 - val_loss: 1.0731
# Epoch 3/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.3472 - loss: 1.1554 - val_accuracy: 0.3833 - val_loss: 1.0698
# Epoch 4/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.3616 - loss: 1.1232 - val_accuracy: 0.5000 - val_loss: 1.0661
# Epoch 5/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.3601 - loss: 1.1116 - val_accuracy: 0.3833 - val_loss: 1.0681
# Epoch 6/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.3396 - loss: 1.1086 - val_accuracy: 0.4500 - val_loss: 1.0670
# Epoch 7/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.3328 - loss: 1.1090 - val_accuracy: 0.4667 - val_loss: 1.0659
# Epoch 8/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.3676 - loss: 1.1006 - val_accuracy: 0.4333 - val_loss: 1.0666
# Epoch 9/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 125s 3s/step - accuracy: 0.3517 - loss: 1.0985 - val_accuracy: 0.4667 - val_loss: 1.0674
# Epoch 10/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 141s 3s/step - accuracy: 0.3805 - loss: 1.0884 - val_accuracy: 0.5167 - val_loss: 1.0635
# Epoch 11/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 134s 3s/step - accuracy: 0.3714 - loss: 1.0874 - val_accuracy: 0.4000 - val_loss: 1.0613
# Epoch 12/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 119s 3s/step - accuracy: 0.3707 - loss: 1.0876 - val_accuracy: 0.5167 - val_loss: 1.0567
# Epoch 13/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.3843 - loss: 1.0859 - val_accuracy: 0.3833 - val_loss: 1.0562
# Epoch 14/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 118s 3s/step - accuracy: 0.3971 - loss: 1.0848 - val_accuracy: 0.4333 - val_loss: 1.0563
# Epoch 15/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 109s 3s/step - accuracy: 0.4009 - loss: 1.0830 - val_accuracy: 0.4500 - val_loss: 1.0575
# ✅ ResNet50 Test Accuracy: 39.74%
#
# 🚀 Training EfficientNetB0...
#
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.3623 - loss: 1.1140 - val_accuracy: 0.3333 - val_loss: 1.1123
# Epoch 2/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 123s 3s/step - accuracy: 0.3230 - loss: 1.1137 - val_accuracy: 0.3333 - val_loss: 1.1007
# Epoch 3/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 131s 3s/step - accuracy: 0.3298 - loss: 1.1086 - val_accuracy: 0.3333 - val_loss: 1.1016
# Epoch 4/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 116s 3s/step - accuracy: 0.3359 - loss: 1.1052 - val_accuracy: 0.3333 - val_loss: 1.0988
# Epoch 5/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 109s 3s/step - accuracy: 0.3056 - loss: 1.1044 - val_accuracy: 0.3333 - val_loss: 1.0988
# Epoch 6/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.3404 - loss: 1.1009 - val_accuracy: 0.3333 - val_loss: 1.1007
# Epoch 7/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.3222 - loss: 1.1022 - val_accuracy: 0.3333 - val_loss: 1.0992
# Epoch 8/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.3411 - loss: 1.1002 - val_accuracy: 0.3333 - val_loss: 1.0996
# Epoch 9/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 113s 3s/step - accuracy: 0.3374 - loss: 1.1016 - val_accuracy: 0.3333 - val_loss: 1.0998
# Epoch 10/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 110s 3s/step - accuracy: 0.3366 - loss: 1.1007 - val_accuracy: 0.3333 - val_loss: 1.0985
# Epoch 11/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.3215 - loss: 1.1011 - val_accuracy: 0.3333 - val_loss: 1.0988
# Epoch 12/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.3336 - loss: 1.0990 - val_accuracy: 0.3333 - val_loss: 1.0985
# Epoch 13/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.3457 - loss: 1.0979 - val_accuracy: 0.3333 - val_loss: 1.0999
# Epoch 14/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.3502 - loss: 1.0993 - val_accuracy: 0.3333 - val_loss: 1.0988
# Epoch 15/15
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.3480 - loss: 1.0993 - val_accuracy: 0.3333 - val_loss: 1.0989
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ EfficientNetB0 Test Accuracy: 33.77%
#
# ================ FINAL RESULT ================
# 🏆 Best Model      : MobileNetV2
# 🎯 Best Accuracy   : 97.35%
# 💾 Model Saved As  : best_plant_disease_model.h5
# =============================================
